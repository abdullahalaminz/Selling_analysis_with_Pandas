# %%
import pandas as pd

# %% [markdown]
# ### Load Data Seat

# %%
DataFrame = pd.read_csv("F:\Data Analysis\Shope\ShopeSellSeat.csv")

# %%
DataFrame
# Out:
#     SerialNo  NameCustomer   Money    DayName  Date  Month  Year
# 0           1          Aria    100     Sunday      1   May  2022
# 1           2          Alim    210     Monday      2   May  2022
# 2           3         Asha     260    Tuesday      3   May  2022
# 3           4         Hamza    150  Wednesday      4   May  2022
# 4           5         Xijas    234   Thursday      5   May  2022
# ..        ...           ...    ...        ...    ...   ...   ...
# 87         88          Renu    675  Wednesday     27  July  2022
# 88         89          Ranu    213   Thursday     28  July  2022
# 89         90          Rana    453     Friday     29  July  2022
# 90         91          Raju    443   Saturday     30  July  2022
# 91         92          Ajad    245     Sunday     31  July  2022
#
# [92 rows x 7 columns]

# %% [markdown]
# ### Some Information Of DataSeat

# %%
DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SerialNo       92 non-null     int64
#  1   NameCustomer   92 non-null     object
#  2   Money          92 non-null     int64
#  3   DayName        92 non-null     object
#  4   Date           92 non-null     int64
#  5   Month          92 non-null     object
#  6   Year           92 non-null     int64
# dtypes: int64(4), object(3)
# memory usage: 5.2+ KB

# %% [markdown]
# #### Dataseat use memory 5.2+ kb

# %% [markdown]
# ### Describe The DataSeat

# %%
DataFrame.shape
# Out:
# (92, 7)

# %%
DataFrame.describe()
# Out:
#        SerialNo        Money      Date     Year
# count   92.00000   92.000000  92.000000    92.0
# mean    46.50000  403.543478  15.836957  2022.0
# std     26.70206  222.422646   8.902743     0.0
# min      1.00000  100.000000   1.000000  2022.0
# 25%     23.75000  234.000000   8.000000  2022.0
# 50%     46.50000  343.500000  16.000000  2022.0
# 75%     69.25000  543.000000  23.250000  2022.0
# max     92.00000  900.000000  31.000000  2022.0

# %% [markdown]
# #### The Dataseat have 7 collum and 92 row. The Mean value is 46

# %% [markdown]
# ### Specific Row and Collum

# %%
DataFrame['Money']
# Out:
# 0     100
# 1     210
# 2     260
# 3     150
# 4     234
#      ...
# 87    675
# 88    213
# 89    453
# 90    443
# 91    245
# Name: Money, Length: 92, dtype: int64

# %%
DataFrame.Money.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 1st 5 row and last 5 row

# %%
DataFrame.head()
# Out:
#    SerialNo  NameCustomer   Money    DayName  Date  Month  Year
# 0          1          Aria    100     Sunday      1   May  2022
# 1          2          Alim    210     Monday      2   May  2022
# 2          3         Asha     260    Tuesday      3   May  2022
# 3          4         Hamza    150  Wednesday      4   May  2022
# 4          5         Xijas    234   Thursday      5   May  2022

# %%
DataFrame.tail()
# Out:
#     SerialNo  NameCustomer   Money    DayName  Date  Month  Year
# 87         88          Renu    675  Wednesday     27  July  2022
# 88         89          Ranu    213   Thursday     28  July  2022
# 89         90          Rana    453     Friday     29  July  2022
# 90         91          Raju    443   Saturday     30  July  2022
# 91         92          Ajad    245     Sunday     31  July  2022

# %% [markdown]
# ### Random 5 Row and Collum

# %%
DataFrame.sample(5)
# Out:
#     SerialNo  NameCustomer   Money    DayName  Date  Month  Year
# 64         65         Summa    456     Monday      4  July  2022
# 26         27          Setu    234     Friday     27   May  2022
# 56         57          Taim    534     Sunday     26  June  2022
# 74         75          Nuli    345   Thursday     14  July  2022
# 59         60          Minu    634  Wednesday     29  June  2022

# %% [markdown]
# ### Total Sell

# %%
Total_sell = DataFrame.Money.sum()
print(" The total sell last 3 month sell is {} Taka only" .format(Total_sell))
# Out:
#  The total sell last 3 month sell is 37126 Taka only

# %% [markdown]
# ### 500 Taka sell

# %%
High_Sell=DataFrame.Money>500

# %%
DataFrame[High_Sell]
# Out:
#     SerialNo  NameCustomer   Money    DayName  Date  Month  Year
# 8           9          Sila    765     Monday      9   May  2022
# 11         12         Sampa    876   Thursday     12   May  2022
# 13         14          Sumi    543   Saturday     14   May  2022
# 16         17          Mamu    543    Tuesday     17   May  2022
# 17         18          Mina    543  Wednesday     18   May  2022
# 22         23          Luna    675     Monday     23   May  2022
# 24         25          Nuli    879  Wednesday     25   May  2022
# 25         26          Rima    534   Thursday     26   May  2022
# 28         29        Sumila    634     Sunday     29   May  2022
# 29         30         Salma    900     Monday     30   May  2022
# 39         40          Rana    765   Thursday      9  June  2022
# 42         43        Anowar    876     Sunday     12  June  2022
# 44         45     Abdul Hai    543    Tuesday     14  June  2022
# ...

# %% [markdown]
# ### Lowest Sell

# %%
Lowsell=DataFrame.sort_values('Money').head
Lowsell
# Out:
# <bound method NDFrame.head of     SerialNo  NameCustomer   Money    DayName  Date  Month  Year
# 0           1          Aria    100     Sunday      1   May  2022
# 71         72          Lili    123     Monday     11  July  2022
# 6           7          Sima    123   Saturday      7   May  2022
# 61         62         Sampa    123     Friday      1  July  2022
# 58         59        Summna    123    Tuesday     28  June  2022
# ..        ...           ...    ...        ...    ...   ...   ...
# 24         25          Nuli    879  Wednesday     25   May  2022
# 55         56       Motaleb    879   Saturday     25  June  2022
# 29         30         Salma    900     Monday     30   May  2022
# 60         61           Lal    900   Thursday     30  June  2022
# 63         64          Sumi    900     Sunday      3  July  2022
#
# [92 rows x 7 columns]>
